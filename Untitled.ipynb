# %%
#IMPORT LIBRARIES

import pandas as pd

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#LOAD THE DATA 

df = pd.read_csv('test.csv')

# %%
df.head()
# Out:
#    User_ID Age      Gender  Platform  Daily_Usage_Time (minutes)  \
# 0      500  27      Female  Snapchat                         120
# 1      488  21  Non-binary  Snapchat                          60
# 2      776  28  Non-binary  Snapchat                         115
# 3      869  27        Male  Telegram                         105
# 4      573  21  Non-binary  Facebook                          55
#
#    Posts_Per_Day  Likes_Received_Per_Day  Comments_Received_Per_Day  \
# 0              4                      40                         18
# 1              1                      18                          7
# 2              3                      38                         18
# 3              3                      48                         20
# 4              3                      17                          7
#
#    Messages_Sent_Per_Day Dominant_Emotion
# 0                     22          Neutral
# 1                     12          Neutral
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   User_ID                     103 non-null    int64
#  1   Age                         103 non-null    object
#  2   Gender                      103 non-null    object
#  3   Platform                    103 non-null    object
#  4   Daily_Usage_Time (minutes)  103 non-null    int64
#  5   Posts_Per_Day               103 non-null    int64
#  6   Likes_Received_Per_Day      103 non-null    int64
#  7   Comments_Received_Per_Day   103 non-null    int64
#  8   Messages_Sent_Per_Day       103 non-null    int64
#  9   Dominant_Emotion            103 non-null    object
# dtypes: int64(6), object(4)
# memory usage: 8.2+ KB

# %%
#DATA CLEANING - SEARCH FOR MISSING VALUES

print(df.isnull().sum())
# Out:
# User_ID                       0
# Age                           0
# Gender                        0
# Platform                      0
# Daily_Usage_Time (minutes)    0
# Posts_Per_Day                 0
# Likes_Received_Per_Day        0
# Comments_Received_Per_Day     0
# Messages_Sent_Per_Day         0
# Dominant_Emotion              0
# dtype: int64

# %%
# 0 missing values

# %%
# CHECK IF GENDER UNIQUE AND IF NOT THEN CHANGE THE DEFECTIVE ONES AS UNCERTAIN

df.Gender.unique()
# Out:
# array(['Female', 'Non-binary', 'Male', '27', 'Marie'], dtype=object)

# %%
df[(df.Gender != 27) & (df.Gender != 'Marie')]
# Out:
#      User_ID Age      Gender  Platform  Daily_Usage_Time (minutes)  \
# 0        500  27      Female  Snapchat                         120
# 1        488  21  Non-binary  Snapchat                          60
# 2        776  28  Non-binary  Snapchat                         115
# 3        869  27        Male  Telegram                         105
# 4        573  21  Non-binary  Facebook                          55
# ..       ...  ..         ...       ...                         ...
# 98       184  22        Male   Twitter                          70
# 99       896  33        Male  LinkedIn                          85
# 100      708  24  Non-binary  Facebook                         110
# 101      993  24        Male  Telegram                          75
# 102       60  27        Male  Facebook                          60
#
#      Posts_Per_Day  Likes_Received_Per_Day  Comments_Received_Per_Day  \
# 0                4                      40                         18
# ...

# %%
df.describe()
# Out:
#           User_ID  Daily_Usage_Time (minutes)  Posts_Per_Day  \
# count  103.000000                  103.000000     103.000000
# mean   521.262136                   88.009709       2.864078
# std    288.949991                   33.979087       1.732326
# min     16.000000                   40.000000       1.000000
# 25%    275.000000                   60.000000       1.000000
# 50%    526.000000                   75.000000       2.000000
# 75%    776.000000                  105.000000       4.000000
# max    997.000000                  200.000000       8.000000
#
#        Likes_Received_Per_Day  Comments_Received_Per_Day  \
# count              103.000000                 103.000000
# mean                33.456311                  13.766990
# std                 23.031426                   8.107372
# min                  5.000000                   2.000000
# 25%                 15.000000                   7.000000
# 50%                 27.000000                  12.000000
# ...

# %%
df.head(10)
# Out:
#    User_ID Age      Gender   Platform  Daily_Usage_Time (minutes)  \
# 0      500  27      Female   Snapchat                         120
# 1      488  21  Non-binary   Snapchat                          60
# 2      776  28  Non-binary   Snapchat                         115
# 3      869  27        Male   Telegram                         105
# 4      573  21  Non-binary   Facebook                          55
# 5      428  25      Female  Instagram                         160
# 6      528  25      Female  Instagram                         160
# 7      773  21  Non-binary   Facebook                          55
# 8      382  24  Non-binary   Snapchat                          85
# 9      505  33        Male   LinkedIn                          45
#
#    Posts_Per_Day  Likes_Received_Per_Day  Comments_Received_Per_Day  \
# 0              4                      40                         18
# 1              1                      18                          7
# ...

# %%
df['Gender'].replace('27', 'Uncertain', inplace=True)
df['Gender'].replace('Marie', 'Uncertain', inplace=True)
# Out:
# C:\Users\Mouli\AppData\Local\Temp\ipykernel_24076\204784942.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Gender'].replace('27', 'Uncertain', inplace=True)
# C:\Users\Mouli\AppData\Local\Temp\ipykernel_24076\204784942.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
# UNIVARIANT ANALYSIS

# %%
plt.figure(figsize = (10, 6))
sns.countplot(x='Gender', data=df, palette='viridis')
plt.title('Gender Distribution For This Survey')
plt.xlabel('GENDER')
plt.ylabel('COUNT')
plt.show()
# Out:
# C:\Users\Mouli\AppData\Local\Temp\ipykernel_24076\4033657723.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Gender', data=df, palette='viridis')

# %%
plt.figure(figsize = (10, 6))
sns.countplot(x='Daily_Usage_Time (minutes)', data=df, palette='viridis')
plt.title('Daily Usage Time For This Survey')
plt.xlabel('Daily Usage Time (minutes)')
plt.ylabel('COUNT')
plt.show()
# Out:
# C:\Users\Mouli\AppData\Local\Temp\ipykernel_24076\1002639096.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Daily_Usage_Time (minutes)', data=df, palette='viridis')

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Dominant_Emotion', data=df, palette='rocket_r')
plt.title('Distribution of Dominant Emotions')
plt.xlabel('Dominant Emotion')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\Mouli\AppData\Local\Temp\ipykernel_24076\1235488281.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Dominant_Emotion', data=df, palette='rocket_r')

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Platform', data=df, palette='icefire')
plt.title('Distribution of Platform')
plt.xlabel('Platform')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\Mouli\AppData\Local\Temp\ipykernel_24076\446004572.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Platform', data=df, palette='icefire')

# %%
#CHECK AGE UNIQUE AND IF NOT THEN DROP

df.Age.unique()
# Out:
# array(['27', '21', '28', '25', '24', '33', '32', '23', '35', '31', '34',
#        '29', '22', '26', '30', 'Male'], dtype=object)

# %%
df = df.drop(df[df['Age'] == 'Male'].index)

# %%
#SORT AGE IN ASCENDING ORDER

sorted_df = df.sort_values(by='Age')

# %%
df
plt.figure(figsize=(10, 6))
sns.countplot(x='Age', data=sorted_df, palette='magma')
plt.title('Distribution of Age')
plt.xlabel('Age Groups')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\Mouli\AppData\Local\Temp\ipykernel_24076\2423493886.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Age', data=sorted_df, palette='magma')

# %%
#BIVARIANT ANALYSIS

# %%
# Create a Barplot of the average daily usage time by platform

plt.figure(figsize = (10, 6))
sns.barplot(x='Platform', y='Daily_Usage_Time (minutes)', data = df, estimator = np.mean, color = 'blue', palette = 'hls')
plt.title('Average Daily Usage Time by Platform')
plt.xlabel('PLATFORM')
plt.ylabel('DAILY USAGE TIME (minutes)')
plt.show()
# Out:
# C:\Users\Mouli\AppData\Local\Temp\ipykernel_24076\673083742.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Platform', y='Daily_Usage_Time (minutes)', data = df, estimator = np.mean, color = 'blue', palette = 'hls')

# %%
plt.figure(figsize = (10, 6))
sns.barplot(x='Gender', y='Daily_Usage_Time (minutes)', data = df, estimator = np.mean, color = 'blue', palette = 'hls')
plt.title('Average Daily Usage Time by Gender')
plt.xlabel('GENDER')
plt.ylabel('DAILY USAGE TIME (minutes)')
plt.show()
# Out:
# C:\Users\Mouli\AppData\Local\Temp\ipykernel_24076\3565446256.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Gender', y='Daily_Usage_Time (minutes)', data = df, estimator = np.mean, color = 'blue', palette = 'hls')

# %%
plt.figure(figsize = (10, 6))
sns.barplot(x='Age', y='Daily_Usage_Time (minutes)', data = sorted_df, estimator = np.mean, color = 'blue', palette = 'hls')
plt.title('Average Daily Usage Time by Age')
plt.xlabel('AGE')
plt.ylabel('DAILY USAGE TIME (minutes)')
plt.show()
# Out:
# C:\Users\Mouli\AppData\Local\Temp\ipykernel_24076\4237785414.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Age', y='Daily_Usage_Time (minutes)', data = sorted_df, estimator = np.mean, color = 'blue', palette = 'hls')

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Platform', hue='Dominant_Emotion', data=df, palette='viridis')
plt.title('Distribution of Dominant Emotions by Platform')
plt.xlabel('Platform')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Gender', hue='Dominant_Emotion', data=df, palette='rocket')
plt.title('Distribution of Dominant Emotions by Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Age', hue='Dominant_Emotion', data=sorted_df, palette='viridis')
plt.title('Distribution of Dominant Emotions by Age')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Daily_Usage_Time (minutes)', hue='Dominant_Emotion', data=sorted_df, palette='magma')
plt.title('Distribution of Dominant Emotions by Daily Usage Time (minutes)')
plt.xlabel('Daily Usage Time (minutes)')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Posts_Per_Day', hue='Dominant_Emotion', data=sorted_df, palette='viridis')
plt.title('Distribution of Dominant Emotions by Posts Per Day')
plt.xlabel('Posts Per Day')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Likes_Received_Per_Day', hue='Dominant_Emotion', data=sorted_df, palette='rocket')
plt.title('Distribution of Dominant Emotions by Likes Received Per Day')
plt.xlabel('Likes Received Per Day')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Comments_Received_Per_Day', hue='Dominant_Emotion', data=sorted_df, palette='viridis')
plt.title('Distribution of Dominant Emotions by Comments Received Per Day')
plt.xlabel('Comments Received Per Day')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Messages_Sent_Per_Day', hue='Dominant_Emotion', data=sorted_df, palette='rocket')
plt.title('Distribution of Dominant Emotions by Messages Sent Per Day')
plt.xlabel('Messages Sent Per Day')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Dominant_Emotion', y='Daily_Usage_Time (minutes)', data=df, palette='magma')
plt.title('Distribution of Daily Usage Time by Dominant Emotion')
plt.xlabel('Dominant Emotion')
plt.ylabel('Daily Usage Time (minutes)')
plt.show()
# Out:
# C:\Users\Mouli\AppData\Local\Temp\ipykernel_24076\2144482244.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Dominant_Emotion', y='Daily_Usage_Time (minutes)', data=df, palette='magma')

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Dominant_Emotion', y='Posts_Per_Day', data=df, palette='magma')
plt.title('Distribution of Posts Per Day by Dominant Emotion')
plt.xlabel('Dominant Emotion')
plt.ylabel('Posts Per Day')
plt.show()
# Out:
# C:\Users\Mouli\AppData\Local\Temp\ipykernel_24076\2291951196.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Dominant_Emotion', y='Posts_Per_Day', data=df, palette='magma')

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Dominant_Emotion', y='Age', data=sorted_df, palette='magma')
plt.title('Distribution of Age by Dominant Emotion')
plt.xlabel('Dominant Emotion')
plt.ylabel('Age')
plt.show()
# Out:
# C:\Users\Mouli\AppData\Local\Temp\ipykernel_24076\803894739.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Dominant_Emotion', y='Age', data=sorted_df, palette='magma')

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Dominant_Emotion', y='Platform', data=df, palette='magma')
plt.title('Distribution of Platform by Dominant Emotion')
plt.xlabel('Dominant Emotion')
plt.ylabel('Platform')
plt.show()
# Out:
# C:\Users\Mouli\AppData\Local\Temp\ipykernel_24076\1153465317.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Dominant_Emotion', y='Platform', data=df, palette='magma')

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Dominant_Emotion', y='Likes_Received_Per_Day', data=df, palette='magma')
plt.title('Distribution of Likes Received Per Day by Dominant Emotion')
plt.xlabel('Dominant Emotion')
plt.ylabel('Likes Received Per Day')
plt.show()
# Out:
# C:\Users\Mouli\AppData\Local\Temp\ipykernel_24076\920405579.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Dominant_Emotion', y='Likes_Received_Per_Day', data=df, palette='magma')

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Dominant_Emotion', y='Comments_Received_Per_Day', data=df, palette='magma')
plt.title('Distribution of Comments Received Per Day by Dominant Emotion')
plt.xlabel('Dominant Emotion')
plt.ylabel('Comments Received Per Day')
plt.show()
# Out:
# C:\Users\Mouli\AppData\Local\Temp\ipykernel_24076\507778940.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Dominant_Emotion', y='Comments_Received_Per_Day', data=df, palette='magma')

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Dominant_Emotion', y='Messages_Sent_Per_Day', data=df, palette='magma')
plt.title('Distribution of Messages Sent Per Day by Dominant Emotion')
plt.xlabel('Dominant Emotion')
plt.ylabel('Messages Sent Per Day')
plt.show()
# Out:
# C:\Users\Mouli\AppData\Local\Temp\ipykernel_24076\738802997.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Dominant_Emotion', y='Messages_Sent_Per_Day', data=df, palette='magma')

# %%
#CORRELATION ANALYSIS

# %%
print(df.dtypes)
# Out:
# User_ID                        int64
# Age                           object
# Gender                        object
# Platform                      object
# Daily_Usage_Time (minutes)     int64
# Posts_Per_Day                  int64
# Likes_Received_Per_Day         int64
# Comments_Received_Per_Day      int64
# Messages_Sent_Per_Day          int64
# Dominant_Emotion              object
# dtype: object

# %%
numeric_df = df.apply(pd.to_numeric, errors='coerce')

# %%
label_enc = LabelEncoder()
df['Age'] = label_enc.fit_transform(df['Age'])
df['Gender'] = label_enc.fit_transform(df['Gender'])
df['Platform'] = label_enc.fit_transform(df['Platform'])
df['Dominant_Emotion'] = label_enc.fit_transform(df['Dominant_Emotion'])

# %%
df_corr = df.drop(columns=['User_ID'])

# %%
non_numeric_columns = df_corr.select_dtypes(exclude=['number']).columns
print("Non-numeric columns in the dataset:", non_numeric_columns)
# Out:
# Non-numeric columns in the dataset: Index([], dtype='object')

# %%
for column in non_numeric_columns:
    df_corr[column] = pd.to_numeric(df_corr[column], errors='coerce')

# %%
correlation_matrix = df_corr.corr()

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
#HANDLING OUTLIERS

df.drop(columns=['User_ID'], inplace=True)

# %%
df_numeric = df.select_dtypes(include=np.number)

Q1 = df_numeric.quantile(0.25)
Q3 = df_numeric.quantile(0.75)
IQR = Q3 - Q1

cut_off = 1.5 * IQR
lower_bound = Q1 - cut_off
upper_bound = Q3 + cut_off

while True:
    for column in df_numeric.columns:
        is_outlier_lower = df[column] < lower_bound[column]
        is_outlier_upper = df[column] > upper_bound[column]
        median = df_numeric[column].median()
        df.loc[is_outlier_lower | is_outlier_upper, column] = median
        Q1 = df[df_numeric.columns].quantile(0.25)
        Q3 = df[df_numeric.columns].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR

        outliers_remaining = ((df[df_numeric.columns] < lower_bound) | (df[df_numeric.columns] > upper_bound)).sum()
    
        if outliers_remaining.sum() == 0:
            break

print('Remaining Outliers:')
print(outliers_remaining)
